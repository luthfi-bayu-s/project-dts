# %%
import pandas as pd
import nltk 
nltk.download('stopwords')
nltk.download('punkt')
import functools
pd.options.display.max_columns = 200
pd.options.mode.chained_assignment = None

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from string import punctuation

from collections import Counter
import re
import numpy as np

from tqdm import tqdm_notebook
tqdm_notebook().pandas()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
data = pd.read_csv('./data/utang.csv')
print(data.shape)
# Out:
# (1532, 18)

# %%
data.head(10)
# Out:
#                 id_str        from_user  \
# 0  1162177127124389890    sammy_frangky
# 1  1162177120312807424      azazalinda7
# 2  1162177098615672832        nasikebul
# 3  1162177059608657920   Gu3buk4nkurawa
# 4  1162177042391040000  Hendrian_Rahman
# 5  1162177011407654912      EnddhyMavis
# 6  1162176975965835264     Rahmadpadli3
# 7  1162176972857864192   Ariell14035948
# 8  1162176970488074240       rizkikitri
# 9  1162176964947402752    semut_ireng98
#
#                                                 text  \
# 0  RT @EDitektif: 29 karyawan Sarinah yang didakw...
# 1  RT @_kuis_: Kuis lagi:\n\nMenurutmu hukum memb...
# 2  RT @semut_ireng98: @nasikebul @ProfesorCiBar @...
# 3  RT @Yana51_08: @RakjatJelita @tigers_killer As...
# 4  @semut_ireng98 @NurmajadVozdh @RismaRH02 @Affa...
# 5  @_kuis_ Wajib dan harus sadar diri bagi yg pun...
# 6  @Muslimi63489533 @jengkelin080 @GilangBudi13 @...
# 7  RT @_kuis_: Kuis lagi:\n\nMenurutmu hukum memb...
# 8  RT @semut_ireng98: @rizkikitri @ProfesorCiBar ...
# 9  @rizkikitri @Pohara5 @DuchessOfPanda @Profesor...
#
#                        created_at                 time  geo_coordinates  \
# 0  Fri Aug 16 01:39:53 +0000 2019  16/08/2019 02:39:53              NaN
# 1  Fri Aug 16 01:39:52 +0000 2019  16/08/2019 02:39:52              NaN
# 2  Fri Aug 16 01:39:47 +0000 2019  16/08/2019 02:39:47              NaN
# 3  Fri Aug 16 01:39:37 +0000 2019  16/08/2019 02:39:37              NaN
# 4  Fri Aug 16 01:39:33 +0000 2019  16/08/2019 02:39:33              NaN
# 5  Fri Aug 16 01:39:26 +0000 2019  16/08/2019 02:39:26              NaN
# 6  Fri Aug 16 01:39:17 +0000 2019  16/08/2019 02:39:17              NaN
# 7  Fri Aug 16 01:39:17 +0000 2019  16/08/2019 02:39:17              NaN
# 8  Fri Aug 16 01:39:16 +0000 2019  16/08/2019 02:39:16              NaN
# 9  Fri Aug 16 01:39:15 +0000 2019  16/08/2019 02:39:15              NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN                      NaN                     NaN
# 2        NaN                      NaN                     NaN
# 3        NaN                      NaN                     NaN
# 4        NaN             1.132156e+18           semut_ireng98
# 5        NaN             1.152190e+18                  _kuis_
# 6        NaN             1.133174e+18         Muslimi63489533
# 7        NaN                      NaN                     NaN
# 8        NaN                      NaN                     NaN
# 9        NaN             8.284222e+17              rizkikitri
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0           3188958402                        NaN
# 1           3241873023                        NaN
# 2            207105018                        NaN
# 3  1160582927320637440                        NaN
# 4             22359565               1.162176e+18
# 5           3096962936               1.162176e+18
# 6  1132132959119482881               1.162174e+18
# 7  1162154087321726977                        NaN
# 8   828422194711580672                        NaN
# 9  1132155782982619137               1.162176e+18
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="http://twitter.com/download/android" ...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://twitter.com/download/android" ...
# 8  <a href="https://mobile.twitter.com" rel="nofo...
# 9  <a href="http://twitter.com/download/android" ...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1155429097...                 101.0
# 1  http://pbs.twimg.com/profile_images/9423451099...                 398.0
# 2  http://pbs.twimg.com/profile_images/1153373379...                2428.0
# 3  http://pbs.twimg.com/profile_images/1160944009...                 108.0
# 4  http://pbs.twimg.com/profile_images/1158266689...                2090.0
# 5  http://pbs.twimg.com/profile_images/1160015596...                 297.0
# 6  http://pbs.twimg.com/profile_images/1132185697...                1434.0
# 7  http://pbs.twimg.com/profile_images/1162154716...                   NaN
# 8  http://pbs.twimg.com/profile_images/1161884445...                2365.0
# 9  http://pbs.twimg.com/profile_images/1132303224...                 948.0
#
#    user_friends_count                   user_location  \
# 0               315.0                             NaN
# 1               534.0           Jawa Timur, Indonesia
# 2              2450.0                         jakarta
# 3               113.0                   United States
# 4              2184.0                Garut, Indonesia
# 5               494.0  Lombok Tengah, Nusa Tenggara B
# 6              2929.0       Sumatera Utara, Indonesia
# 7                35.0                             NaN
# 8              1784.0                               -
# 9              1326.0                             NaN
#
#                                           status_url  \
# 0  http://twitter.com/sammy_frangky/statuses/1162...
# 1  http://twitter.com/azazalinda7/statuses/116217...
# 2  http://twitter.com/nasikebul/statuses/11621770...
# 3  http://twitter.com/Gu3buk4nkurawa/statuses/116...
# 4  http://twitter.com/Hendrian_Rahman/statuses/11...
# 5  http://twitter.com/EnddhyMavis/statuses/116217...
# 6  http://twitter.com/Rahmadpadli3/statuses/11621...
# 7  http://twitter.com/Ariell14035948/statuses/116...
# 8  http://twitter.com/rizkikitri/statuses/1162176...
# 9  http://twitter.com/semut_ireng98/statuses/1162...
#
#                                         entities_str
# 0  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 1  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 2  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 3  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 4  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 5  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 6  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 7  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 8  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 9  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...

# %%
data.from_user.value_counts(normalize=True).plot(kind='line', grid=True, figsize=(20, 10))

# %%
data = data.drop_duplicates('text')

# %%
data = data[~data['text'].isnull()]
print(data.shape)
# Out:
# (1206, 18)

# %%
data = data[(data.text.map(len) > 140) & (data.text.map(len) <= 300)]
data.reset_index(inplace=True, drop=True)
print(data.shape)
# Out:
# (239, 18)

# %%
data.text.map(len).hist(figsize=(15, 5), bins=100)

# %%
data = data.sample(200, random_state=42)
data.reset_index(inplace=True, drop=True)
data.head(10)
# Out:
#                 id_str       from_user  \
# 0  1162174022819274752   83_nurjamilah
# 1  1162176481134403585       mgsgathan
# 2  1162163370276974593      JPurnomo69
# 3  1162161395552514048          UNS752
# 4  1162161815331065856     NuroelHoeda
# 5  1162154120142188545  DirhamsyahRyan
# 6  1162150424306040833       RismaRH02
# 7  1162164132629454848        M_G1LANG
# 8  1162176284580913152      rizkikitri
# 9  1162157795879161858    p4dr1_chozan
#
#                                                 text  \
# 0  RT @Profeson9: Met pagi Parlemen SUSU &amp; KR...
# 1  @_kuis_ Wajib min, dalam agama Islam semua dos...
# 2  @EDitektif @MichelAdamAnyar Kemanusiaan berpih...
# 3  Kembaliin semua berikut kekayaan alam Indonesi...
# 4  @TofaGarisLurus @Twitter opo² an iki Pak...Kok...
# 5  Lewati Makam Siti Khadijah\nHabib Hanif Baca Q...
# 6  Utang Luar Negeri RI Naik 10,1 Persen - https:...
# 7  @Profeson9 @Billy_Lagee @MichelAdamAnyar @Ryiz...
# 8  @NKRI_RI @aiek_esthreem @Etam394gmailco1 @semu...
# 9  Waaaww ,, \nMakin banyak kasbon aje ni nanti.\...
#
#                        created_at                 time  geo_coordinates  \
# 0  Fri Aug 16 01:27:33 +0000 2019  16/08/2019 02:27:33              NaN
# 1  Fri Aug 16 01:37:19 +0000 2019  16/08/2019 02:37:19              NaN
# 2  Fri Aug 16 00:45:14 +0000 2019  16/08/2019 01:45:14              NaN
# 3  Fri Aug 16 00:37:23 +0000 2019  16/08/2019 01:37:23              NaN
# 4  Fri Aug 16 00:39:03 +0000 2019  16/08/2019 01:39:03              NaN
# 5  Fri Aug 16 00:08:28 +0000 2019  16/08/2019 01:08:28              NaN
# 6  Thu Aug 15 23:53:47 +0000 2019  16/08/2019 00:53:47              NaN
# 7  Fri Aug 16 00:48:15 +0000 2019  16/08/2019 01:48:15              NaN
# 8  Fri Aug 16 01:36:33 +0000 2019  16/08/2019 02:36:33              NaN
# 9  Fri Aug 16 00:23:05 +0000 2019  16/08/2019 01:23:05              NaN
#
#    user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        NaN                      NaN                     NaN
# 1        NaN             1.152190e+18                  _kuis_
# 2        NaN             1.029300e+18               EDitektif
# 3        NaN                      NaN                     NaN
# 4        NaN             1.136101e+18          TofaGarisLurus
# 5        NaN                      NaN                     NaN
# 6        NaN                      NaN                     NaN
# 7        NaN             1.142292e+18               Profeson9
# 8        NaN             1.156949e+18                 NKRI_RI
# 9        NaN                      NaN                     NaN
#
#       from_user_id_str  in_reply_to_status_id_str  \
# 0           1687359906                        NaN
# 1            896907643               1.162176e+18
# 2   951265436728836096               1.162150e+18
# 3  1134453703769874432                        NaN
# 4   953905561141047296               1.162027e+18
# 5  1138378582361722880                        NaN
# 6  1142242143198568448                        NaN
# 7           4671595033               1.162140e+18
# 8   828422194711580672               1.162145e+18
# 9  1028645617629724674                        NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="https://mobile.twitter.com" rel="nofo...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://twitter.com/download/android" ...
# 8  <a href="https://mobile.twitter.com" rel="nofo...
# 9  <a href="http://twitter.com/download/android" ...
#
#                                    profile_image_url  user_followers_count  \
# 0  http://pbs.twimg.com/profile_images/1162133110...                1524.0
# 1  http://pbs.twimg.com/profile_images/1076445844...                 106.0
# 2  http://pbs.twimg.com/profile_images/1035720946...                 479.0
# 3  http://pbs.twimg.com/profile_images/1161802801...                 709.0
# 4  http://pbs.twimg.com/profile_images/1161674262...                 987.0
# 5  http://pbs.twimg.com/profile_images/1151823759...                 285.0
# 6  http://pbs.twimg.com/profile_images/1162147667...                1217.0
# 7  http://pbs.twimg.com/profile_images/1160227523...                2129.0
# 8  http://pbs.twimg.com/profile_images/1161884445...                2365.0
# 9  http://pbs.twimg.com/profile_images/1145866848...                1033.0
#
#    user_friends_count               user_location  \
# 0              1887.0                         NaN
# 1               168.0                         NaN
# 2               474.0                         NaN
# 3               855.0                         BDG
# 4              1235.0        Dublin City, Ireland
# 5               315.0           Tangerang, Banten
# 6               877.0                         NaN
# 7              2327.0                   Indonesia
# 8              1784.0                           -
# 9              1458.0  Jakarta Barat, DKI Jakarta
#
#                                           status_url  \
# 0  http://twitter.com/83_nurjamilah/statuses/1162...
# 1  http://twitter.com/mgsgathan/statuses/11621764...
# 2  http://twitter.com/JPurnomo69/statuses/1162163...
# 3  http://twitter.com/UNS752/statuses/11621613955...
# 4  http://twitter.com/NuroelHoeda/statuses/116216...
# 5  http://twitter.com/DirhamsyahRyan/statuses/116...
# 6  http://twitter.com/RismaRH02/statuses/11621504...
# 7  http://twitter.com/M_G1LANG/statuses/116216413...
# 8  http://twitter.com/rizkikitri/statuses/1162176...
# 9  http://twitter.com/p4dr1_chozan/statuses/11621...
#
#                                         entities_str
# 0  {"hashtags":[],"symbols":[],"user_mentions":[{...
# 1  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 2  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 3  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 4  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 5  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 6  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 7  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 8  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...
# 9  {"hashtags":[{"text":"UtangBanyakHarga2Melonja...

# %%
stop_words = []
f = open('./data/stopword.txt', 'r')
for l in f.readlines():
    stop_words.append(l.replace('\n', ''))
additional_stop_words = ['t', 'will']
stop_words += additional_stop_words
print(len(stop_words))
# Out:
# 760

# %%
import functools
def _removeNonAscii(s): 
    return "".join(i for i in s if ord(i)<128)

def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"what's", "what is ", text)
    text = text.replace('(ap)', '')
    text = re.sub(r"\'s", " is ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r"\\", "", text)
    text = re.sub(r"\'", "", text)    
    text = re.sub(r"\"", "", text)
    text = re.sub('[^a-zA-Z ?!]+', '', text)
    text = _removeNonAscii(text)
    text = text.strip()
    return text

# %%
def tokenizer(text):
    text = clean_text(text)    
    tokens = [word_tokenize(sent) for sent in sent_tokenize(text)]
    tokens = list(functools.reduce(lambda x,y: x+y, tokens))
    tokens = list(filter(lambda token: token not in (stop_words + list(punctuation)) , tokens))
    return tokens

# %%
data['text'] = data['text'].map(lambda d: str(d))
data['tokens'] = data['text'].progress_map(lambda d: tokenizer(d))
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))

# %%
for descripition, tokens in zip(data['text'].head(5), data['tokens'].head(5)):
    print(':', descripition)
    print('tokens:', tokens)
    print()
# Out:
# : RT @Profeson9: Met pagi Parlemen SUSU &amp; KR
# @Billy_Lagee
# @MichelAdamAnyar
# @Profeson9
# @RyizondR
# @RissaRR02
# @RismaRichi
# @Bawel_Girl
# @M_G1LANG
# @elamawar1
# @ParicaraNyai
# @DuchessOfPanda
# @amira_swandary
# @NurmajadVozdh
# @BidadariOposisi
# @AmaZanea00
# @Shyin90
# @PutriAi15784229
# 👇
# #UtangBanyakHarga2Melonjak
# tokens: ['rt', 'profeson', 'met', 'pagi', 'parlemen', 'susu', 'amp', 'kr', 'billylagee', 'micheladamanyar', 'profeson', 'ryizondr', 'rissarr', 'rismarichi', 'bawelgirl', 'mglang', 'elamawar', 'paricaranyai', 'duchessofpanda', 'amiraswandary', 'nurmajadvozdh', 'bidadarioposisi', 'amazanea', 'shyin', 'putriai', 'utangbanyakhargamelonjak']
#
# : @_kuis_ Wajib min, dalam agama Islam semua dosa akan di ampuni ketika meninggal syahid tapi tidak dengan hutang...  #UtangBanyakHarga2Melonjak
# tokens: ['kuis', 'wajib', 'min', 'agama', 'islam', 'dosa', 'ampuni', 'meninggal', 'syahid', 'hutang', 'utangbanyakhargamelonjak']
#
# : @EDitektif @MichelAdamAnyar Kemanusiaan berpihak pd kebenaran , kedzoliman menghakimi tanpa nurani
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#
# ✊✊✊✊
# tokens: ['editektif', 'micheladamanyar', 'kemanusiaan', 'berpihak', 'pd', 'kebenaran', 'kedzoliman', 'menghakimi', 'nurani', 'utangbanyakhargamelonjak', 'utangbanyakhargamelonjak']
#
# : Kembaliin semua berikut kekayaan alam Indonesia yg di kuasai aseng dan asing.
# Siiippp..... 😁
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/L6IOI8KHdy
# tokens: ['kembaliin', 'kekayaan', 'alam', 'indonesia', 'yg', 'kuasai', 'aseng', 'asing', 'siiippp', 'utangbanyakhargamelonjak', 'utangbanyakhargamelonjak']
#
# : @TofaGarisLurus @Twitter opo² an iki Pak...Kok tambah Fantastis...
# dari kemaren gelar tiker,nggak ada tanggapan.
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# tokens: ['tofagarislurus', 'twitter', 'opo', 'an', 'iki', 'fantastis', 'kemaren', 'gelar', 'tiker', 'nggak', 'tanggapan', 'utangbanyakhargamelonjak', 'utangbanyakhargamelonjak']

# %%
def keywords(text):
    tokens = data[data['text'] == text]['tokens']
    alltokens = []
    for token_list in tokens:
        alltokens += token_list
    counter = Counter(alltokens)
    return counter.most_common(10)

# %%
data['text'] = data['text'].map(lambda d: str(d))
data['tokens'] = data['text'].progress_map(lambda d: tokenizer(d))
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))

# %%
for text in set(data['text']):
    print('text :', text)
    print('top 10 keywords:', keywords(text))
    print('---')
# Out:
# text : TAGAR kita pagi ini mulai jam 06:00:
# #UtangBanyakHarga2Melonjak
#
# Yang ingin ikut viralkan TAGAR ini,
#
# 1. Sila RT, like, reply tuit2 yang ada TAGAR
# #UtangBanyakHarga2Melonjak
#
# 2. Tambahkan TAGAR
# #UtangBanyakHarga2Melonjak
# di tuitan masing2.
#
# Jangan campur TAGAR lain
# top 10 keywords: [('tagar', 5), ('utangbanyakhargamelonjak', 3), ('pagi', 1), ('jam', 1), ('viralkan', 1), ('sila', 1), ('rt', 1), ('like', 1), ('reply', 1), ('tuit', 1)]
# ---
# text : RT @DirhamsyahRyan: Ketika sang suami menyindir sang istri :D, entah apa yang akan terjadi setelahnya. Ternyata benar, memang mencari kambing hitam itu adalah cara yang paling mudah, efektif dan efisien.
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/2RWn5k0ySg
# top 10 keywords: [('sang', 2), ('utangbanyakhargamelonjak', 2), ('rt', 1), ('dirhamsyahryan', 1), ('suami', 1), ('menyindir', 1), ('istri', 1), ('d', 1), ('setelahnya', 1), ('mencari', 1)]
# ---
# text : RT @Affan_indra: Capek-capek ngerayu @RismaRH02 eh malah dipanggil om... Apa aku harus nyanyi sambil main gitar... Kaya Candra ???
# #UtangBanyakHarga2Melonjak https://t.co/X5fr9vqevZ
# top 10 keywords: [('capek', 2), ('rt', 1), ('affanindra', 1), ('ngerayu', 1), ('rismarh', 1), ('eh', 1), ('dipanggil', 1), ('om', 1), ('nyanyi', 1), ('main', 1)]
# ---
# text : Memang mantap saran2 yang dikeluarkan oleh Prof. Akal sehat ini, yg mana tidak pernah bisa dicerna oleh mereka2 yang mulutnya lebih besar daripada otaknya.
#
# https://t.co/fRrcb8EeHc
#
# #UtangBanyakHarga2Melonjak https://t.co/Ad5Wd0qRhQ
# top 10 keywords: [('mantap', 1), ('saran', 1), ('dikeluarkan', 1), ('prof', 1), ('akal', 1), ('sehat', 1), ('yg', 1), ('dicerna', 1), ('mulutnya', 1), ('otaknya', 1)]
# ---
# text : TAGAR kita pagi ini mulai jam 06:00:
# #UtangBanyakHarga2Melonjak
#
# Yang ingin ikut viralkan TAGAR ini,
#
# 1. Sila RT, like, reply tuit2 yang ada TAGAR
# #UtangBanyakHarga2Melonjak
#
# 2. Tambahkan TAGAR
# #UtangBanyakHarga2Melonjak
# di tuitan masing2.
#
# Jangan campur TAGAR lain
# top 10 keywords: [('tagar', 5), ('utangbanyakhargamelonjak', 3), ('pagi', 1), ('jam', 1), ('viralkan', 1), ('sila', 1), ('rt', 1), ('like', 1), ('reply', 1), ('tuit', 1)]
# ---
# text : @aiek_esthreem tante jgn ngamuk...biarlah siburung yg ngamukk...
# eh bukn ding....😂😂
#
# kurkuuruyukkkk...itukan suara perutkuhhhh😁😂😅
#
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('aiekesthreem', 1), ('tante', 1), ('jgn', 1), ('ngamuk', 1), ('biarlah', 1), ('siburung', 1), ('yg', 1), ('ngamukk', 1), ('eh', 1), ('bukn', 1)]
# ---
# text : @Profeson9 @Billy_Lagee @MichelAdamAnyar @RyizondR @RissaRR02 @RismaRichi @Bawel_Girl @M_G1LANG @elamawar1 @ParicaraNyai @DuchessOfPanda @amira_swandary @NurmajadVozdh @BidadariOposisi @AmaZanea00 @Shyin90 @PutriAi15784229 Selamat pagi juga 🙏🙏
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('profeson', 1), ('billylagee', 1), ('micheladamanyar', 1), ('ryizondr', 1), ('rissarr', 1), ('rismarichi', 1), ('bawelgirl', 1), ('mglang', 1), ('elamawar', 1)]
# ---
# text : TAGAR kita pagi ini mulai jam 06:00:
# #UtangBanyakHarga2Melonjak
# Yang ingin ikut viralkan TAGAR ini,
# 1. Sila RT, like, reply tuit2 yang ada TAGAR
# #UtangBanyakHarga2Melonjak
# 2. Tambahkan TAGAR
# #UtangBanyakHarga2Melonjak
# Di TL masing2
# Jangan campur TAGAR lain
# cc @MichelAdamAnyar
# top 10 keywords: [('tagar', 5), ('utangbanyakhargamelonjak', 3), ('pagi', 1), ('jam', 1), ('viralkan', 1), ('sila', 1), ('rt', 1), ('like', 1), ('reply', 1), ('tuit', 1)]
# ---
# text : كُلُّ أَمْرٍ ذِي بَالٍ لاَ يُبْدَأُ فِيهِ بِحَمْدِ اللَّهِ، فَهُوَ أَقْطَعُ
#
# “Setiap perbuatan yang baik yang tidak dimulai dengan membaca hamdalah, maka akan terputus (keberkahannya).” (HR. Ibn Hibban)
# Edisi menyebar kebaikan.
#
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('perbuatan', 1), ('membaca', 1), ('hamdalah', 1), ('terputus', 1), ('keberkahannya', 1), ('hr', 1), ('ibn', 1), ('hibban', 1), ('edisi', 1), ('menyebar', 1)]
# ---
# text : Jangan ngaku2 sebagai tuhan ya bro
# 😂
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# Mark Zuckerberg Jadi Orang Paling Ditakuti di Dunia https://t.co/yIppBQ2SXE
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('ngaku', 1), ('tuhan', 1), ('ya', 1), ('bro', 1), ('mark', 1), ('zuckerberg', 1), ('orang', 1), ('ditakuti', 1), ('dunia', 1)]
# ---
# text : @MichelAdamAnyar Setuju...
# #UtangBanyakHarga2Melonjak
# Mengapa harga kebutuhan pokok gak bisa dikontrol pemerintah? Apa kerja nya?
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('micheladamanyar', 1), ('setuju', 1), ('harga', 1), ('kebutuhan', 1), ('pokok', 1), ('gak', 1), ('dikontrol', 1), ('pemerintah', 1), ('kerja', 1)]
# ---
# text : @_kuis_ Wajib min, dalam agama Islam semua dosa akan di ampuni ketika meninggal syahid tapi tidak dengan hutang...  #UtangBanyakHarga2Melonjak
# top 10 keywords: [('kuis', 1), ('wajib', 1), ('min', 1), ('agama', 1), ('islam', 1), ('dosa', 1), ('ampuni', 1), ('meninggal', 1), ('syahid', 1), ('hutang', 1)]
# ---
# text : RT @Ryizond08: @RismaRH02 Itulah hasil rebutan kursi, hanya untuk bisa korupsi tanpa memikir rakyat sengsara dgn harga" melonjak naik.
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('ryizond', 1), ('rismarh', 1), ('hasil', 1), ('rebutan', 1), ('kursi', 1), ('korupsi', 1), ('memikir', 1), ('rakyat', 1)]
# ---
# text : @riani_212 @NKRI_RI @aiek_esthreem @CuteP4nd4 @OurLove_Yuki @HDouboegiez @Ru__Chee @KiJaga_Baya @Cantiikkk___693 @khalsa86_mdn @HaqYang @Pohara5 @VanYrvanz @NongNayara @Majapahitprabu @dyanr99 @julie_my_name @Orang_Atjeh Aduuuh... Kasihan anak anak kita dong neng...
#
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('anak', 2), ('riani', 1), ('nkriri', 1), ('aiekesthreem', 1), ('cutepnd', 1), ('ourloveyuki', 1), ('hdouboegiez', 1), ('ruchee', 1), ('kijagabaya', 1), ('cantiikkk', 1)]
# ---
# text : @Hilmi28 😃 bisa aja ustad
#
# Semoga Allah beri kesabaran
#
# Dan istiqomah amar maruf nahi munkar
#
# Tetap ingatkan masyarakat bahwa kita ini  #UtangBanyakHarga2Melonjak
#
# Semoga Allah jaga kita dunia akhirat
# top 10 keywords: [('semoga', 2), ('allah', 2), ('hilmi', 1), ('aja', 1), ('ustad', 1), ('kesabaran', 1), ('istiqomah', 1), ('amar', 1), ('maruf', 1), ('nahi', 1)]
# ---
# text : @ustadtengkuzul Luar biasa negara kita ini, kekayaan alamnya melimpah ruah tapi hutangnya gak ketulungan. Udah gitu, pemimpinnya nyindir, eh yg kena malah istrinya. Kami rakyat cuma bisa nonton aja
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/lS5pjoNjXC
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('ustadtengkuzul', 1), ('negara', 1), ('kekayaan', 1), ('alamnya', 1), ('melimpah', 1), ('ruah', 1), ('hutangnya', 1), ('gak', 1), ('ketulungan', 1)]
# ---
# text : Bang anies cukup membalas bully an bkn dgn kata-kata melainkan dgn karya-karya. Sungguh cerdas Gubernur satu ini..
#
# #UtangBanyakHarga2Melonjak https://t.co/aLKdWjVKJW
# top 10 keywords: [('dgn', 2), ('karya', 2), ('bang', 1), ('anies', 1), ('membalas', 1), ('bully', 1), ('an', 1), ('bkn', 1), ('sungguh', 1), ('cerdas', 1)]
# ---
# text : RT @mustofaismail79: @aiek_esthreem Trus kerjanya pak jokowi ma jajaranya itu apa ko bisa2nya #UtangBanyakHarga2Melonjak
# Kesian kluargaku klw belanja nangis mulu krn
#  #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('mustofaismail', 1), ('aiekesthreem', 1), ('trus', 1), ('kerjanya', 1), ('jokowi', 1), ('ma', 1), ('jajaranya', 1), ('ko', 1)]
# ---
# text : RT @BinNuh_: Utang....
# " Hina di siang hari, Gelisah di malam hari "
#
# #UtangBanyakHarga2Melonjak
# #JumatBerkah
# #StopRiba https://t.co/BAmkqQA3Mq
# top 10 keywords: [('rt', 1), ('binnuh', 1), ('utang', 1), ('hina', 1), ('siang', 1), ('gelisah', 1), ('malam', 1), ('utangbanyakhargamelonjak', 1), ('jumatberkah', 1), ('stopriba', 1)]
# ---
# text : @riani_212 @NKRI_RI @aiek_esthreem @CuteP4nd4 @OurLove_Yuki @HDouboegiez @Ru__Chee @KiJaga_Baya @Cantiikkk___693 @khalsa86_mdn @HaqYang @Pohara5 @VanYrvanz @NongNayara @Majapahitprabu @dyanr99 @julie_my_name @Orang_Atjeh Pagi neng geulis... Kumaha kabar na???
#
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('riani', 1), ('nkriri', 1), ('aiekesthreem', 1), ('cutepnd', 1), ('ourloveyuki', 1), ('hdouboegiez', 1), ('ruchee', 1), ('kijagabaya', 1), ('cantiikkk', 1), ('khalsamdn', 1)]
# ---
# text : RT @Asep67213597: @bayangan_semar @BecaknyaWiwis Kasian para pencari kerja udh urus surat sana sini udh antri udah tertib  eh gk di terima #UtangBanyakHarga2Melonjak #UtangBanyakHarga2Melonjak
# top 10 keywords: [('udh', 2), ('utangbanyakhargamelonjak', 2), ('rt', 1), ('asep', 1), ('bayangansemar', 1), ('becaknyawiwis', 1), ('kasian', 1), ('pencari', 1), ('kerja', 1), ('urus', 1)]
# ---
# text : Utang Luar Negeri RI Naik 10,1 Persen - https://t.co/I7jDiiY7uL https://t.co/y15Wc2i8VG
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('utang', 1), ('negeri', 1), ('ri', 1), ('persen', 1)]
# ---
# text : Apa kabar Indonesia..
# Sudah benarkah kita MERDEKA ?
#
# Merdeka atau mati ??
# (Sudah merdeka tapi setengah mati 😢😢)
#
# Jangan lupa mainkan tagarnya
# 👇#UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/iKRocEcqJN
# top 10 keywords: [('merdeka', 3), ('mati', 2), ('utangbanyakhargamelonjak', 2), ('kabar', 1), ('indonesia', 1), ('lupa', 1), ('mainkan', 1), ('tagarnya', 1)]
# ---
# text : 05:55
# Salfol Ya .. 🙏
#            👇
# @kanseulir
# @UyokBack
# @hacknet__71
# @MichelAdamAnyar
# @4NN4_5U3Z4NN
# @021_P354W1K
# @nancyfabiola99
# @kolak_VI
# @aiek_esthreem
# @BidadariOposisi
# @hera_loebs
# @lGrabo13
# #UtangBanyakHarga2Melonjak
# 🙏🙏
#
# Selamat Pagi
#  🇲🇨74 Tahun Indonesia Merdeka🇲🇨 https://t.co/K8tovfWSYs
# top 10 keywords: [('salfol', 1), ('ya', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('pwk', 1), ('nancyfabiola', 1), ('kolakvi', 1)]
# ---
# text : @djasMpu @budimandjatmiko @bandabening wkwkkwkwk....auto ngakak nih :D. yah begitulah mereka :D
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('d', 2), ('utangbanyakhargamelonjak', 2), ('djasmpu', 1), ('budimandjatmiko', 1), ('bandabening', 1), ('wkwkkwkwk', 1), ('auto', 1), ('ngakak', 1), ('nih', 1), ('yah', 1)]
# ---
# text : Assalamualaikum, awali pagi ini dengan Bismillah, dahulukan Allah disetiap aktivitas agar selalu mendapatkan keridhaan-Nya
#
# Jangan lupa tagarnya Kawan
#  👇👇👇
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/tXzSlLtyMm
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('assalamualaikum', 1), ('awali', 1), ('pagi', 1), ('bismillah', 1), ('dahulukan', 1), ('allah', 1), ('disetiap', 1), ('aktivitas', 1), ('keridhaan', 1)]
# ---
# text : @cinnamon_irish @MichelAdamAnyar para elite lbh mementingkan diri sendiri
# tidak ada kepedulian..
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('cinnamonirish', 1), ('micheladamanyar', 1), ('elite', 1), ('lbh', 1), ('mementingkan', 1), ('kepedulian', 1)]
# ---
# text : RT @DirhamsyahRyan: Clear ya, mana meme yang asli dan mana yang palsu. Ini ada2 aja orang iseng yang bikin meme hoax begini.... dasar kadal kebon
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/dzUXwioSW3
# top 10 keywords: [('meme', 2), ('utangbanyakhargamelonjak', 2), ('rt', 1), ('dirhamsyahryan', 1), ('clear', 1), ('ya', 1), ('asli', 1), ('palsu', 1), ('aja', 1), ('orang', 1)]
# ---
# text : @Muslimi63489533 @jengkelin080 @GilangBudi13 @GendisManis16 @Al_Fakir_ @DazaiSan08 @Momon_Egen @_Konnichiwa31_ @Lelepon16 @ScouserHandry @JengSrie080 @MrBin008 @UllbimaNtb Idiot
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('muslimi', 1), ('jengkelin', 1), ('gilangbudi', 1), ('gendismanis', 1), ('alfakir', 1), ('dazaisan', 1), ('momonegen', 1), ('konnichiwa', 1), ('lelepon', 1), ('scouserhandry', 1)]
# ---
# text : @LemonPeres @jatila11 @gusmusgusmu Kenaikan harga akan.memicu inflasi, coba cek harga cabe merah saat ini, Rp.100 ribu per kg.
# Ueddann...
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('harga', 2), ('utangbanyakhargamelonjak', 2), ('lemonperes', 1), ('jatila', 1), ('gusmusgusmu', 1), ('kenaikan', 1), ('memicu', 1), ('inflasi', 1), ('coba', 1), ('cek', 1)]
# ---
# text : TABOK MULUTNYA PARA PEMBENCI BENDERA TAUHID....
# PLLLLAAAAAAAKKKKKKKK.......
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/LqofG6mznM
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('tabok', 1), ('mulutnya', 1), ('pembenci', 1), ('bendera', 1), ('tauhid', 1), ('pllllaaaaaaakkkkkkkk', 1)]
# ---
# text : @RismaRH02 Itulah hasil rebutan kursi, hanya untuk bisa korupsi tanpa memikir rakyat sengsara dgn harga" melonjak naik.
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rismarh', 1), ('hasil', 1), ('rebutan', 1), ('kursi', 1), ('korupsi', 1), ('memikir', 1), ('rakyat', 1), ('sengsara', 1), ('dgn', 1)]
# ---
# text : RT @RismaRH02: Percuma pertumbuhan pembangunan naik jika tak diimbangi oleh pertumbuhan ekonomi.
# Insfratruktur yang dibangunpun kebanyakan salah sasaran. Utamakan kepentingan rakyat seharusnya, agar ekonomi ikut tumbuh saat membangun.
#
# #UtangBanyakHarga2Melonjak
# https://t.co/ZjSm8QfnQx
# top 10 keywords: [('pertumbuhan', 2), ('ekonomi', 2), ('rt', 1), ('rismarh', 1), ('pembangunan', 1), ('diimbangi', 1), ('insfratruktur', 1), ('dibangunpun', 1), ('kebanyakan', 1), ('salah', 1)]
# ---
# text : @Profeson9 @Billy_Lagee @MichelAdamAnyar @RyizondR @RissaRR02 @RismaRichi @Bawel_Girl @elamawar1 @ParicaraNyai @DuchessOfPanda @amira_swandary @NurmajadVozdh @BidadariOposisi @AmaZanea00 @Shyin90 @PutriAi15784229 pagi juga prof..
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('profeson', 1), ('billylagee', 1), ('micheladamanyar', 1), ('ryizondr', 1), ('rissarr', 1), ('rismarichi', 1), ('bawelgirl', 1), ('elamawar', 1), ('paricaranyai', 1)]
# ---
# text : Cerdas, ini padahal capaska lho ya. Ko bisa lebih cerdas daripada nachiro ya?
#
# https://t.co/iumTdcaUli
#
# #UtangBanyakHarga2Melonjak https://t.co/6WMaot0Prt
# top 10 keywords: [('cerdas', 2), ('ya', 2), ('capaska', 1), ('lho', 1), ('ko', 1), ('nachiro', 1), ('utangbanyakhargamelonjak', 1)]
# ---
# text : Ada yang tau ga dongeng anjing serakah dan sepotong tulang??
# Kasih tau dong 😁
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#  Jokowi Sindir Emak-Emak yang Suka Beli Tas Impor, Netizen Ungkap Koleksi Tas Branded Iriana  -- https://t.co/AvjgoAGZan
# top 10 keywords: [('tau', 2), ('utangbanyakhargamelonjak', 2), ('emak', 2), ('tas', 2), ('ga', 1), ('dongeng', 1), ('anjing', 1), ('serakah', 1), ('sepotong', 1), ('tulang', 1)]
# ---
# text : RT @Ning198: @jagger86031021 @Sulisti14281557 Makin jarang ke toko, bikin sakit mata lihat harga dan sakit hati ga bisa beli
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('sakit', 2), ('utangbanyakhargamelonjak', 2), ('rt', 1), ('ning', 1), ('jagger', 1), ('sulisti', 1), ('jarang', 1), ('toko', 1), ('bikin', 1), ('mata', 1)]
# ---
# text : @RismaRH02 @VanYrvanz @khalsa86_mdn @AntoniRaja Cinta Cantik Cakep terserah pilih yg mana...
# Lho ko om sih ... eh salah ga jadi... C nya itu camu...
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('rismarh', 1), ('vanyrvanz', 1), ('khalsamdn', 1), ('antoniraja', 1), ('cinta', 1), ('cantik', 1), ('cakep', 1), ('terserah', 1), ('pilih', 1), ('yg', 1)]
# ---
# text : Polisi sita BB 1.024.193 kosmetik &amp; obat-obatan, 4.350 bungkus bahan pangan, 774.036 suku cadang kendaraan, 48.641 barang elektronik &amp; 8 unit truk. Tersangka dijerat UU 36/2014 tentang Kesehatan dan UU 18/2012 tentang Pangan. #UtangBanyakHarga2Melonjak
# https://t.co/3bK9GuLMxZ
# top 10 keywords: [('amp', 2), ('pangan', 2), ('uu', 2), ('polisi', 1), ('sita', 1), ('bb', 1), ('kosmetik', 1), ('obat', 1), ('obatan', 1), ('bungkus', 1)]
# ---
# text : @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @BidadariOposisi @hera_loebs @lGrabo13 Kita lom Merdeka
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1), ('kolakvi', 1), ('aiekesthreem', 1)]
# ---
# text : RT @NugrahaIrwin: Bukan Urusan Saya......
#
# Selamat Pagi Sahabat Twitt.....
#
# Jum'at Barokah 🙏😇
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/5970YZyMdr
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('nugrahairwin', 1), ('urusan', 1), ('selamat', 1), ('pagi', 1), ('sahabat', 1), ('twitt', 1), ('jum', 1), ('at', 1)]
# ---
# text : RT @gilang15592071: @NKRI_RI @jagger86031021 Semangat pagi bung mick and all
# ngopi dulu..
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/2l51dbqWKB
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('gilang', 1), ('nkriri', 1), ('jagger', 1), ('semangat', 1), ('pagi', 1), ('mick', 1), ('and', 1), ('all', 1)]
# ---
# text : pemerintah malahan maksa rakyatnya utk beli beras, garam, cangkul, gula, kedelai, bawang semua nya Import , ngomong ora mikir
#
# Cc : @Aminuddinamir72
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('pemerintah', 1), ('maksa', 1), ('rakyatnya', 1), ('utk', 1), ('beli', 1), ('beras', 1), ('garam', 1), ('cangkul', 1), ('gula', 1)]
# ---
# text : Ekonomi RI Tumbuh 5%, Ekonom UI: Tanpa Presiden Pun Bisa
#
# Welcome to the jungle
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#
# https://t.co/xKOG6Wqu6Z
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('ekonomi', 1), ('ri', 1), ('tumbuh', 1), ('ekonom', 1), ('ui', 1), ('presiden', 1), ('welcome', 1), ('to', 1), ('the', 1)]
# ---
# text : RT @NiCemplux: @aiek_esthreem tante jgn ngamuk...biarlah siburung yg ngamukk...
# eh bukn ding....😂😂
#
# kurkuuruyukkkk...itukan suara perutkuhhhh😁😂😅
#
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('rt', 1), ('nicemplux', 1), ('aiekesthreem', 1), ('tante', 1), ('jgn', 1), ('ngamuk', 1), ('biarlah', 1), ('siburung', 1), ('yg', 1), ('ngamukk', 1)]
# ---
# text : RT @curang_kpu: SEJARAH AKAN MENCATAT BAHWA ADA REJIM YG SDH KALAH TELAK TAPI DI PAKSAIN MENANG AMA MK KPU BAWASLU DAN SELURUH JAJARAN PEMERINTAHAN REJIM TOGOG TANPA RASA MALU....SUNGGUH MEMUAKKAN!!!!#UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/bsBbCjARHH
# top 10 keywords: [('rejim', 2), ('utangbanyakhargamelonjak', 2), ('rt', 1), ('curangkpu', 1), ('sejarah', 1), ('mencatat', 1), ('yg', 1), ('sdh', 1), ('kalah', 1), ('telak', 1)]
# ---
# text : RT @RismaRH02: Utang sudah menumpuk, harga-harga pada melonjak naik,
# itu menteri kerja gk ya,
# apa hanya kerja untuk kantong sendiri?
#
# #UtangBanyakHarga2Melonjak
#
# https://t.co/Nt1WWbTSwv
# top 10 keywords: [('harga', 2), ('kerja', 2), ('rt', 1), ('rismarh', 1), ('utang', 1), ('menumpuk', 1), ('melonjak', 1), ('menteri', 1), ('gk', 1), ('ya', 1)]
# ---
# text : @aiek_esthreem Kutang banyak,ngga pernah ganti.bau tau
# 😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂🙏🙏
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('aiekesthreem', 1), ('kutang', 1), ('ngga', 1), ('ganti', 1), ('bau', 1), ('tau', 1)]
# ---
# text : @Affan_indra @MichelAdamAnyar Yo bana semangek Abang berjuang jo tagar, sampai" takaibana hpnyo dibuek 😆😆
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('affanindra', 1), ('micheladamanyar', 1), ('yo', 1), ('bana', 1), ('semangek', 1), ('abang', 1), ('berjuang', 1), ('jo', 1), ('tagar', 1)]
# ---
# text : @SetiadiYudizaza @CNBLUE_9 @aiek_esthreem @MichelAdamAnyar @gemacan2 @f4iryP1nk @YongL4dy @amira_swandary @p3jalan @RissaRR02 @Shyin90 @lGrabo13 @Mel4yu @Mia_suhandi_ @itsmeajalah3 @AmoebaF3 @JackMar39013302 @wakabento @CintaKita_OkE Nyungsepnya meroket 😝
#
# Euh.. #UtangBanyakHarga2Melonjak
# Vangke
# top 10 keywords: [('setiadiyudizaza', 1), ('cnblue', 1), ('aiekesthreem', 1), ('micheladamanyar', 1), ('gemacan', 1), ('firypnk', 1), ('yongldy', 1), ('amiraswandary', 1), ('pjalan', 1), ('rissarr', 1)]
# ---
# text : RT @Ryizond08: TAGAR kita pagi ini mulai
# #UtangBanyakHarga2Melonjak
#
# Yang ingin ikut viralkan TAGAR ini,
#
# 1. Sila RT, like, reply tuit2 yang ada TAGAR
# #UtangBanyakHarga2Melonjak
#
# 2. Tambahkan TAGAR
# #UtangBanyakHarga2Melonjak
# di tuitan masing2
#
# Jangan campur TAGAR lain
# Cc @MichelAdamAnyar
# top 10 keywords: [('tagar', 5), ('utangbanyakhargamelonjak', 3), ('rt', 2), ('ryizond', 1), ('pagi', 1), ('viralkan', 1), ('sila', 1), ('like', 1), ('reply', 1), ('tuit', 1)]
# ---
# text : Semoga Allah lindungi mereka semua dan keluarganya..
#
# Dan semoga yg melakukan kezaliman itu, mendapatkan ganjaran yg setimpal.
#
# #UtangBanyakHarga2Melonjak https://t.co/Rxygl5jxnj
# top 10 keywords: [('semoga', 2), ('yg', 2), ('allah', 1), ('lindungi', 1), ('keluarganya', 1), ('kezaliman', 1), ('ganjaran', 1), ('setimpal', 1), ('utangbanyakhargamelonjak', 1)]
# ---
# text : @Affan_indra @RissaRR02 @MichelAdamAnyar Selamat jalan dan sampai bertemu kembali juga
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('affanindra', 1), ('rissarr', 1), ('micheladamanyar', 1), ('selamat', 1), ('jalan', 1), ('bertemu', 1)]
# ---
# text : RT @iinSrt: Assalamualiakum
#
# Pagi sobat tweeps jumat barokah perbanyak doa,istiqhfar dan sholawat
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/88lKKVXH17
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('iinsrt', 1), ('assalamualiakum', 1), ('pagi', 1), ('sobat', 1), ('tweeps', 1), ('jumat', 1), ('barokah', 1), ('perbanyak', 1)]
# ---
# text : Selalu Bertempur dan Berharap agar mendapatkan hasil , Di coba bermain di LudoQQ bermain dengan ID hoki yang akan di dapatkan , Pelayanan tercepat dan Sopan :)
#
# #JumatBerkah
# #BawangPutihPartaiMerah
# #UtangBanyakHarga2Melonjak
# #KANGMINHEE
# #LEEEUNSANG https://t.co/p2V701WV3K
# top 10 keywords: [('bermain', 2), ('bertempur', 1), ('berharap', 1), ('hasil', 1), ('coba', 1), ('ludoqq', 1), ('id', 1), ('hoki', 1), ('dapatkan', 1), ('pelayanan', 1)]
# ---
# text : Kain boleh luntur lusuh dan terkoyak...tp cintaku padamu.... merah putih  takkan lekang oleh waktu... 🙏😊🤗#UtangBanyakHarga2Melonjak #UtangBanyakHarga2Melonjak https://t.co/hQOFAFvqoa
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('kain', 1), ('luntur', 1), ('lusuh', 1), ('terkoyak', 1), ('tp', 1), ('cintaku', 1), ('padamu', 1), ('merah', 1), ('putih', 1)]
# ---
# text : @nancyfabiola99 @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @Kolak_VI @aiek_esthreem @hera_loebs @lGrabo13 Bantu naikin tagarnya yu sis 🙏🏻🙏🏻
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/h4UcVSLzEs
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('nancyfabiola', 1), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('kolakvi', 1), ('aiekesthreem', 1)]
# ---
# text : Clear ya, ini ulah dari kadal kebon yg hobby bikin hoax. Cuma sayang, klo yg kek begini aparat berwajib selalu diam, pura2 ga tau, ga pernah gerak cepat. Tapi ya sudahlah, mo apa lagi.
#
# https://t.co/qfdqhJwrti
#
# #UtangBanyakHarga2Melonjak https://t.co/W92TSOGWyK
# top 10 keywords: [('ya', 2), ('yg', 2), ('ga', 2), ('clear', 1), ('ulah', 1), ('kadal', 1), ('kebon', 1), ('hobby', 1), ('bikin', 1), ('hoax', 1)]
# ---
# text : @RismaRH02 @RismaRichi @MichelAdamAnyar 😂😂😂😂
#
# Izinkan aku genggam tanganmu dengan sah.
# Agar aku dapat melindungimu atas izinya-Nya.
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rismarh', 1), ('rismarichi', 1), ('micheladamanyar', 1), ('izinkan', 1), ('genggam', 1), ('tanganmu', 1), ('sah', 1), ('melindungimu', 1), ('izinya', 1)]
# ---
# text : @aiek_esthreem GASS POLLL 5
# UTANG LG UTANG LG....KAPAN BYRNYA..PEA...
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/18EZUHMOBA
# top 10 keywords: [('utang', 2), ('lg', 2), ('utangbanyakhargamelonjak', 2), ('aiekesthreem', 1), ('gass', 1), ('polll', 1), ('byrnya', 1), ('pea', 1)]
# ---
# text : @Affan_indra @MichelAdamAnyar Alhamdulillah
# Semoga amak acok mendoakan Habib Rizieq Shihab dan ulama" lainnya 😊😊
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('affanindra', 1), ('micheladamanyar', 1), ('alhamdulillah', 1), ('semoga', 1), ('amak', 1), ('acok', 1), ('mendoakan', 1), ('habib', 1), ('rizieq', 1)]
# ---
# text : RT @jatila11: @Profeson9 @Billy_Lagee @MichelAdamAnyar @RyizondR @RissaRR02 @RismaRichi @Bawel_Girl @M_G1LANG @elamawar1 @ParicaraNyai @DuchessOfPanda @amira_swandary @NurmajadVozdh @BidadariOposisi @AmaZanea00 @Shyin90 @PutriAi15784229 Stor tagar... #UtangBanyakHarga2Melonjak
# top 10 keywords: [('rt', 1), ('jatila', 1), ('profeson', 1), ('billylagee', 1), ('micheladamanyar', 1), ('ryizondr', 1), ('rissarr', 1), ('rismarichi', 1), ('bawelgirl', 1), ('mglang', 1)]
# ---
# text : RT @HafisSapardi: @EDitektif @MichelAdamAnyar Hegemoni ekonomi hilangnya harga diri
# #UtangBanyakHarga2Melonjak
# Rezim cleptocrazy korbankan para kurcaci
# #UtangBanyakHarga2Melonjak https://t.co/WMu2DiNM6L
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('hafissapardi', 1), ('editektif', 1), ('micheladamanyar', 1), ('hegemoni', 1), ('ekonomi', 1), ('hilangnya', 1), ('harga', 1), ('rezim', 1)]
# ---
# text : @aiek_esthreem GASSS POLLL TRUS AMPE MENTOK...
# YG KERJA BNYK KENA PHK...TRUS NNT YG LULUSN SI SMK SMA MO KERJA DIMN GOG....DASAR REJIM PENGKHIANAT...RKYT INDONESIA DIBUAT MATI PELAN PELAN...
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('trus', 2), ('yg', 2), ('kerja', 2), ('pelan', 2), ('utangbanyakhargamelonjak', 2), ('aiekesthreem', 1), ('gasss', 1), ('polll', 1), ('ampe', 1), ('mentok', 1)]
# ---
# text : @aiek_esthreem Trus kerjanya pak jokowi ma jajaranya itu apa ko bisa2nya #UtangBanyakHarga2Melonjak
# Kesian kluargaku klw belanja nangis mulu krn
#  #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('aiekesthreem', 1), ('trus', 1), ('kerjanya', 1), ('jokowi', 1), ('ma', 1), ('jajaranya', 1), ('ko', 1), ('bisanya', 1), ('kesian', 1)]
# ---
# text : RT @curang_kpu: WOOOIIIIII BANI TOGOG MEDIA TOGOG REJIM TOGOG.....INI YG LOE PUJA PUJA ELUK ELUKAN.....AMIT AMIT DAH!!!
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/pgD4uP2ZVG
# top 10 keywords: [('togog', 3), ('puja', 2), ('amit', 2), ('utangbanyakhargamelonjak', 2), ('rt', 1), ('curangkpu', 1), ('woooiiiiii', 1), ('bani', 1), ('media', 1), ('rejim', 1)]
# ---
# text : @Profeson9 @Billy_Lagee @MichelAdamAnyar @RyizondR @RissaRR02 @RismaRichi @Bawel_Girl @M_G1LANG @elamawar1 @ParicaraNyai @DuchessOfPanda @amira_swandary @NurmajadVozdh @BidadariOposisi @AmaZanea00 @Shyin90 @PutriAi15784229 Slnat pagi. #UtangBanyakHarga2Melonjak
# top 10 keywords: [('profeson', 1), ('billylagee', 1), ('micheladamanyar', 1), ('ryizondr', 1), ('rissarr', 1), ('rismarichi', 1), ('bawelgirl', 1), ('mglang', 1), ('elamawar', 1), ('paricaranyai', 1)]
# ---
# text : RT @jagger86031021: #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#
# Pak @Jokowi anda sudah tidak mampu, mundurlah.....
#
# https://t.co/CWibozrIPf
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('jagger', 1), ('jokowi', 1), ('mundurlah', 1)]
# ---
# text : RT @27ARin17: Semoga Allah lindungi mereka semua dan keluarganya..
#
# Dan semoga yg melakukan kezaliman itu, mendapatkan ganjaran yg setimpal.
#
# #UtangBanyakHarga2Melonjak https://t.co/Rxygl5jxnj
# top 10 keywords: [('semoga', 2), ('yg', 2), ('rt', 1), ('arin', 1), ('allah', 1), ('lindungi', 1), ('keluarganya', 1), ('kezaliman', 1), ('ganjaran', 1), ('setimpal', 1)]
# ---
# text : SEJARAH AKAN MENCATAT BAHWA ADA REJIM YG SDH KALAH TELAK TAPI DI PAKSAIN MENANG AMA MK KPU BAWASLU DAN SELURUH JAJARAN PEMERINTAHAN REJIM TOGOG TANPA RASA MALU....SUNGGUH MEMUAKKAN!!!!#UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/bsBbCjARHH
# top 10 keywords: [('rejim', 2), ('utangbanyakhargamelonjak', 2), ('sejarah', 1), ('mencatat', 1), ('yg', 1), ('sdh', 1), ('kalah', 1), ('telak', 1), ('paksain', 1), ('menang', 1)]
# ---
# text : Assallamu'allaikum🙏
# Selamat pagi sobat &amp; sobit🙋
# Selamat hari Jum'at, jangan sampai tak Sholat Jum'at😵🔨
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Mel9njak https://t.co/mRYZ7KONma
# top 10 keywords: [('selamat', 2), ('jum', 2), ('at', 2), ('assallamu', 1), ('allaikum', 1), ('pagi', 1), ('sobat', 1), ('amp', 1), ('sobit', 1), ('sholat', 1)]
# ---
# text : RT @Sulisti14281557: @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @BidadariOposisi @hera_loebs @lGrabo13 done
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('sulisti', 1), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1)]
# ---
# text : @Khadori8 Saya sedang berpikir bagaimana kondisi negara ini ke depannya.
# Sepertinya makin suram dan mundur. Disatu sisi kita harus tetap semangat tak boleh menyerah, disisi lainya banyak sampah masalah yang makin menumpuk. Rakyat kecil yang selalu menderita.
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('khadori', 1), ('berpikir', 1), ('kondisi', 1), ('negara', 1), ('depannya', 1), ('suram', 1), ('mundur', 1), ('disatu', 1), ('sisi', 1), ('semangat', 1)]
# ---
# text : Clear ya, mana meme yang asli dan mana yang palsu. Ini ada2 aja orang iseng yang bikin meme hoax begini.... dasar kadal kebon
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/dzUXwioSW3
# top 10 keywords: [('meme', 2), ('utangbanyakhargamelonjak', 2), ('clear', 1), ('ya', 1), ('asli', 1), ('palsu', 1), ('aja', 1), ('orang', 1), ('iseng', 1), ('bikin', 1)]
# ---
# text : RT @NuroelHoeda: Selamat....biarpun lamabat ,asalkan terus meningkat.
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/VT2bYffFXT
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('nuroelhoeda', 1), ('selamat', 1), ('biarpun', 1), ('lamabat', 1), ('meningkat', 1)]
# ---
# text : @ArLex_Wu @Candramasi1 @jokowi Sedikit bagi yg butuh, sangat membekas. Sekedar bagi yg perlu sungguh berkesan.
#
# Jangan kebalik yg pak @jokowi ...Bahagia utk Siapa Beban Berat Kusut Sulit utk Siapa..
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('yg', 3), ('jokowi', 2), ('utk', 2), ('utangbanyakhargamelonjak', 2), ('arlexwu', 1), ('candramasi', 1), ('butuh', 1), ('membekas', 1), ('sekedar', 1), ('sungguh', 1)]
# ---
# text : @the_X08 @lGrabo13 @jokowi @idtodaydotco Apa hendak dikata drpd : bukan urusan saya.
# #UtangBanyakHarga2Melonjak
# Anakx jg pny barang" branded
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('thex', 1), ('lgrabo', 1), ('jokowi', 1), ('idtodaydotco', 1), ('dikata', 1), ('drpd', 1), ('urusan', 1), ('anakx', 1), ('jg', 1)]
# ---
# text : Kembaliin semua berikut kekayaan alam Indonesia yg di kuasai aseng dan asing.
# Siiippp..... 😁
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/L6IOI8KHdy
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('kembaliin', 1), ('kekayaan', 1), ('alam', 1), ('indonesia', 1), ('yg', 1), ('kuasai', 1), ('aseng', 1), ('asing', 1), ('siiippp', 1)]
# ---
# text : @Muslimi63489533 @jengkelin080 @GilangBudi13 @GendisManis16 @Al_Fakir_ @DazaiSan08 @Momon_Egen @_Konnichiwa31_ @Lelepon16 @ScouserHandry @JengSrie080 @MrBin008 @UllbimaNtb Tolol
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('muslimi', 1), ('jengkelin', 1), ('gilangbudi', 1), ('gendismanis', 1), ('alfakir', 1), ('dazaisan', 1), ('momonegen', 1), ('konnichiwa', 1), ('lelepon', 1), ('scouserhandry', 1)]
# ---
# text : RT @jagger86031021: #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#
# Impor Bawang Putih Berujung ke KPK, Buwas: Bukti ada Mafia https://t.co/XvowxNvawK via @idtodaydotco
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('jagger', 1), ('impor', 1), ('bawang', 1), ('putih', 1), ('berujung', 1), ('kpk', 1), ('buwas', 1), ('bukti', 1)]
# ---
# text : @Mrmarshall_rama @aniesbaswedan Togog gemblung gk berani upacara di tanahnya sendiri reklsmasi masih wilay indonesia #UtangBanyakHarga2Melonjak #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('mrmarshallrama', 1), ('aniesbaswedan', 1), ('togog', 1), ('gemblung', 1), ('gk', 1), ('berani', 1), ('upacara', 1), ('tanahnya', 1), ('reklsmasi', 1)]
# ---
# text : @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @hera_loebs @lGrabo13 Wilujeung enjing
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1), ('kolakvi', 1), ('aiekesthreem', 1)]
# ---
# text : @DuchessOfPanda @M_G1LANG @RismaRH02 @Profeson9 @Billy_Lagee @MichelAdamAnyar @RyizondR @RismaRichi @Bawel_Girl @elamawar1 @ParicaraNyai @amira_swandary @NurmajadVozdh @BidadariOposisi @AmaZanea00 @Shyin90 @PutriAi15784229 Betul kakak mut
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('duchessofpanda', 1), ('mglang', 1), ('rismarh', 1), ('profeson', 1), ('billylagee', 1), ('micheladamanyar', 1), ('ryizondr', 1), ('rismarichi', 1), ('bawelgirl', 1)]
# ---
# text : @HangJeb47599466 Suruh saja anak SD jadi pleciden biar tidak timbul syak wasangka
#
# 😥😥😥
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('hangjeb', 1), ('suruh', 1), ('anak', 1), ('sd', 1), ('pleciden', 1), ('biar', 1), ('timbul', 1), ('syak', 1), ('wasangka', 1)]
# ---
# text : @EDitektif @MichelAdamAnyar Hegemoni ekonomi hilangnya harga diri
# #UtangBanyakHarga2Melonjak
# Rezim cleptocrazy korbankan para kurcaci
# #UtangBanyakHarga2Melonjak https://t.co/WMu2DiNM6L
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('editektif', 1), ('micheladamanyar', 1), ('hegemoni', 1), ('ekonomi', 1), ('hilangnya', 1), ('harga', 1), ('rezim', 1), ('cleptocrazy', 1), ('korbankan', 1)]
# ---
# text : negara +62 bener-bener lg apes punya pimpinan model jae. tp bego warga negaranya ko milih dia lg uda tau iq ny jongkok #UtangBanyakHarga2Melonjak
# top 10 keywords: [('bener', 2), ('lg', 2), ('negara', 1), ('apes', 1), ('pimpinan', 1), ('model', 1), ('jae', 1), ('tp', 1), ('bego', 1), ('warga', 1)]
# ---
# text : @IyubovM4t @anggarini90 @MichelAdamAnyar Maka dari itu anda harus subscribe cenel yutub saya biar pendapatan saya meningkat. Link dibio jangan lupa like, komen n share!!!! Terima kasih. #UtangBanyakHarga2Melonjak
# top 10 keywords: [('iyubovmt', 1), ('anggarini', 1), ('micheladamanyar', 1), ('subscribe', 1), ('cenel', 1), ('yutub', 1), ('biar', 1), ('pendapatan', 1), ('meningkat', 1), ('link', 1)]
# ---
# text : @bayangan_semar @BecaknyaWiwis Kasian para pencari kerja udh urus surat sana sini udh antri udah tertib  eh gk di terima #UtangBanyakHarga2Melonjak #UtangBanyakHarga2Melonjak
# top 10 keywords: [('udh', 2), ('utangbanyakhargamelonjak', 2), ('bayangansemar', 1), ('becaknyawiwis', 1), ('kasian', 1), ('pencari', 1), ('kerja', 1), ('urus', 1), ('surat', 1), ('antri', 1)]
# ---
# text : RT @nasikebul: TAGAR kita pagi ini mulai jam 06:00:
# #UtangBanyakHarga2Melonjak
# Yang ingin ikut viralkan TAGAR ini,
# 1. Sila RT, like, reply tuit2 yang ada TAGAR
# #UtangBanyakHarga2Melonjak
# 2. Tambahkan TAGAR
# #UtangBanyakHarga2Melonjak
# Di TL masing2
# Jangan campur TAGAR lain
# cc @MichelAdamAnyar
# top 10 keywords: [('tagar', 5), ('utangbanyakhargamelonjak', 3), ('rt', 2), ('nasikebul', 1), ('pagi', 1), ('jam', 1), ('viralkan', 1), ('sila', 1), ('like', 1), ('reply', 1)]
# ---
# text : @budimandjatmiko @bandabening Nih sekalian gw buka polling disini, semua dari kalian silahkan berpartisipasi. Monggo dipilih, mana yang berbahaya? PKI atau HTI? Waku polling hanya 1 hari doang, cukup lah ya.
#
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('polling', 2), ('budimandjatmiko', 1), ('bandabening', 1), ('nih', 1), ('gw', 1), ('buka', 1), ('silahkan', 1), ('berpartisipasi', 1), ('monggo', 1), ('dipilih', 1)]
# ---
# text : @aiek_esthreem Bismillah
# Jumat Barokah
#
# Jamane jaman kredit, mulai kredit laku, kredit home, kredit online, kredit renten, kredit motor, kredit rumah, dan satu lagi kredit apa yah, oh..kredit ganti presiden ?
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('kredit', 9), ('utangbanyakhargamelonjak', 2), ('aiekesthreem', 1), ('bismillah', 1), ('jumat', 1), ('barokah', 1), ('jamane', 1), ('jaman', 1), ('laku', 1), ('home', 1)]
# ---
# text : @021_P354W1K @_andy_ch @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @BidadariOposisi @hera_loebs @lGrabo13 Done
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('pwk', 1), ('andych', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1), ('kolakvi', 1)]
# ---
# text : @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @hera_loebs @lGrabo13 #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/7Q4jqsfu8N
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1), ('kolakvi', 1), ('aiekesthreem', 1)]
# ---
# text : @Muslimi63489533 @jengkelin080 @GilangBudi13 @GendisManis16 @Al_Fakir_ @DazaiSan08 @Momon_Egen @_Konnichiwa31_ @Lelepon16 @ScouserHandry @JengSrie080 @MrBin008 @UllbimaNtb Penjilat hutahaen
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('muslimi', 1), ('jengkelin', 1), ('gilangbudi', 1), ('gendismanis', 1), ('alfakir', 1), ('dazaisan', 1), ('momonegen', 1), ('konnichiwa', 1), ('lelepon', 1), ('scouserhandry', 1)]
# ---
# text : @nochebonx Jiahhh.. ikutan lahhh... ga da elo ga rame... yakin dah lo ga bakalan menang.. so.. ikutan yaaaa 😋
#
# Euh.. #UtangBanyakHarga2Melonjak
# Vangke
# top 10 keywords: [('ga', 3), ('ikutan', 2), ('nochebonx', 1), ('jiahhh', 1), ('lahhh', 1), ('da', 1), ('elo', 1), ('rame', 1), ('dah', 1), ('lo', 1)]
# ---
# text : @BidadariOposisi @Profeson9 @Billy_Lagee @MichelAdamAnyar @RyizondR @RismaRichi @Bawel_Girl @elamawar1 @ParicaraNyai @DuchessOfPanda @amira_swandary @NurmajadVozdh @AmaZanea00 @Shyin90 @PutriAi15784229 pagi juga @BidadariOposisi
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# Met aktivitas
# top 10 keywords: [('bidadarioposisi', 2), ('utangbanyakhargamelonjak', 2), ('profeson', 1), ('billylagee', 1), ('micheladamanyar', 1), ('ryizondr', 1), ('rismarichi', 1), ('bawelgirl', 1), ('elamawar', 1), ('paricaranyai', 1)]
# ---
# text : RT @sang_pnakluk: MERDEKA
#
# Saya Paling NKRI
# Saya Paling NASIONALISME
# Saya Paling PANCASILAIS
# Saya Paling .................... ?!!
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/QS9qiHuWcg
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('sangpnakluk', 1), ('merdeka', 1), ('nkri', 1), ('nasionalisme', 1), ('pancasilais', 1)]
# ---
# text : Untuk membuat pemerintah berpikir ulang untuk impor caranya dgn tidak membeli barang yang mereka impor.
# Bikin rugi pemerintah dgn membeli produk rakyatnya.
# Tapi susahnya tidak ada pembeda antara produk impor dan produk sendiri
# #UtangBanyakHarga2Melonjak https://t.co/0VnS9JRS5H
# top 10 keywords: [('impor', 3), ('produk', 3), ('pemerintah', 2), ('dgn', 2), ('membeli', 2), ('berpikir', 1), ('ulang', 1), ('barang', 1), ('bikin', 1), ('rugi', 1)]
# ---
# text : RT @jagger86031021: TAGAR kita pagi ini mulai jam 06:00:
# #UtangBanyakHarga2Melonjak
#
# Yang ingin ikut viralkan TAGAR ini,
#
# 1. Sila RT, like, reply tuit2 yang ada TAGAR
# #UtangBanyakHarga2Melonjak
#
# 2. Tambahkan TAGAR
# #UtangBanyakHarga2Melonjak
# di tuitan masing2.
#
# Jangan campur TAGAR lain
# top 10 keywords: [('tagar', 5), ('utangbanyakhargamelonjak', 3), ('rt', 2), ('jagger', 1), ('pagi', 1), ('jam', 1), ('viralkan', 1), ('sila', 1), ('like', 1), ('reply', 1)]
# ---
# text : Waaaww ,,
# Makin banyak kasbon aje ni nanti.
#
# Klean Gak suka,,,? pegih dari sinih !!
#
# Togog pasti kegirangan ,nenek sri masuk kabinet jokowi lagi
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/9spGNQMS05
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('waaaww', 1), ('kasbon', 1), ('aje', 1), ('ni', 1), ('klean', 1), ('gak', 1), ('suka', 1), ('pegih', 1), ('sinih', 1)]
# ---
# text : Pagi yg harusnya cerah jadi mendung kepikiran #UtangBanyakHarga2Melonjak
# Semua karena iblis berbaju putih yg sedang pura" jadi malaikat.. ingat...!!!!
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('yg', 2), ('utangbanyakhargamelonjak', 2), ('pagi', 1), ('cerah', 1), ('mendung', 1), ('kepikiran', 1), ('iblis', 1), ('berbaju', 1), ('putih', 1), ('pura', 1)]
# ---
# text : Muk remuk... #UtangBanyakHarga2Melonjak
# Boss.... naikin gaji kok elitnya.. karyawan bawah ga dinaikin gajinya malah pajaknya yg dinaikin...
# Karyawanmu tuh
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('dinaikin', 2), ('muk', 1), ('remuk', 1), ('boss', 1), ('naikin', 1), ('gaji', 1), ('elitnya', 1), ('karyawan', 1), ('ga', 1)]
# ---
# text : @jagger86031021 @Ning198 @Sulisti14281557 tiwul mana tiwul...😅sekalian napak tilas 74 tahun... 🇲🇨
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('tiwul', 2), ('utangbanyakhargamelonjak', 2), ('jagger', 1), ('ning', 1), ('sulisti', 1), ('napak', 1), ('tilas', 1)]
# ---
# text : RT @semut_ireng98: @MarcoSatria02 @NKRI_RI @aiek_esthreem @Etam394gmailco1 @rizkikitri @VanYrvanz Semoga kita termasuk dalam golongan hamdhan syakuro... aamiin..
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('semutireng', 1), ('marcosatria', 1), ('nkriri', 1), ('aiekesthreem', 1), ('etamgmailco', 1), ('rizkikitri', 1), ('vanyrvanz', 1), ('semoga', 1)]
# ---
# text : @nancyfabiola99 @lGrabo13 @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @Kolak_VI @aiek_esthreem @hera_loebs Have a great day sis 🙏🏻🙏🏻
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('nancyfabiola', 1), ('lgrabo', 1), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('kolakvi', 1)]
# ---
# text : @QiraniAyara @SetiadiYudizaza Ormas terdepan bantu bencana alam
# #UtangBanyakHarga2Melonjak
# Jum'at Mubarak
# #UtangBanyakHarga2Melonjak
# Salkomsel
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('qiraniayara', 1), ('setiadiyudizaza', 1), ('ormas', 1), ('terdepan', 1), ('bantu', 1), ('bencana', 1), ('alam', 1), ('jum', 1), ('at', 1)]
# ---
# text : @FatkurIsti @Orangbiasaaje @MichelAdamAnyar Kate takok jwbne pancet ae
# #UtangBanyakHarga2Melonjak
# Jum'at Mubarak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('fatkuristi', 1), ('orangbiasaaje', 1), ('micheladamanyar', 1), ('kate', 1), ('takok', 1), ('jwbne', 1), ('pancet', 1), ('ae', 1), ('jum', 1)]
# ---
# text : @idtodaydotco DNAx bisnis ea ngumpulin kepeng , min
# #UtangBanyakHarga2Melonjak
# Jum'at Mubarak
# #UtangBanyakHarga2Melonjak
# Salam SUKSES pol bat mimin n kel
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('idtodaydotco', 1), ('dnax', 1), ('bisnis', 1), ('ea', 1), ('ngumpulin', 1), ('kepeng', 1), ('min', 1), ('jum', 1), ('at', 1)]
# ---
# text : Met pagi Parlemen SUSU &amp; KR
# @Billy_Lagee
# @MichelAdamAnyar
# @Profeson9
# @RyizondR
# @RissaRR02
# @RismaRichi
# @Bawel_Girl
# @M_G1LANG
# @elamawar1
# @ParicaraNyai
# @DuchessOfPanda
# @amira_swandary
# @NurmajadVozdh
# @BidadariOposisi
# @AmaZanea00
# @Shyin90
# @PutriAi15784229
# 👇
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('met', 1), ('pagi', 1), ('parlemen', 1), ('susu', 1), ('amp', 1), ('kr', 1), ('billylagee', 1), ('micheladamanyar', 1), ('profeson', 1), ('ryizondr', 1)]
# ---
# text : @TofaGarisLurus @Twitter opo² an iki Pak...Kok tambah Fantastis...
# dari kemaren gelar tiker,nggak ada tanggapan.
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('tofagarislurus', 1), ('twitter', 1), ('opo', 1), ('an', 1), ('iki', 1), ('fantastis', 1), ('kemaren', 1), ('gelar', 1), ('tiker', 1)]
# ---
# text : @aiek_esthreem GASSS POOLLLL 6...
# SAAT INI UANG 100RB HNY CUKUP UNT KEBTHN SEHR....NAH KLU GAJI NY HNY 2JT DAN ADA LG KLU KRG...APALAGI NGK KERJA...BGMN ATASI NY JAE....LOE DKK BIKIN SUSAH RAKYT INDONESIA...REJIM PENDUSTA
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/eoYfblzaWv
# top 10 keywords: [('hny', 2), ('klu', 2), ('ny', 2), ('utangbanyakhargamelonjak', 2), ('aiekesthreem', 1), ('gasss', 1), ('poollll', 1), ('uang', 1), ('rb', 1), ('unt', 1)]
# ---
# text : @Sulisti14281557 @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @hera_loebs @lGrabo13 D O N E . . .
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/CMyUqAqXri
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('sulisti', 1), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1), ('kolakvi', 1)]
# ---
# text : Masya Allaah.
# Keterbatasan TIDAK HARUS menjadikan seseorang itu terbatas.
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/3FVkcnBCRK
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('masya', 1), ('allaah', 1), ('keterbatasan', 1), ('menjadikan', 1), ('terbatas', 1)]
# ---
# text : 74 thn merdeka, 7 X ganti nakhoda, negeri ini belum mampu ujudkan keadilan sosial bagi semua.
# Ketidakpuasan berpotensi mencari jalannya sendiri &amp; inilah yg menjadi ancaman utama bagi utuhnya NKRI.
# Jng label pencari keadilan dng sebutan RADIKAL.
#   #UtangBanyakHarga2Melonjak
# top 10 keywords: [('keadilan', 2), ('thn', 1), ('merdeka', 1), ('x', 1), ('ganti', 1), ('nakhoda', 1), ('negeri', 1), ('ujudkan', 1), ('sosial', 1), ('ketidakpuasan', 1)]
# ---
# text : RT @k3nzie201: Lagi2
# Piala kaleng minta belas kasihan
# 😍😍
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# Mendagri Imbau Masyarakat Saksikan Pidato Kenegaraan Jokowi, Warganet: Bodo Amat! -- https://t.co/BalPQVBLKF
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('knzie', 1), ('piala', 1), ('kaleng', 1), ('belas', 1), ('kasihan', 1), ('mendagri', 1), ('imbau', 1), ('masyarakat', 1)]
# ---
# text : Lewati Makam Siti Khadijah
# Habib Hanif Baca Qasidah
# Kesukaan Mbah Moen
#
# https://t.co/ikGDzE0u7N
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/53STkxMlNC
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('lewati', 1), ('makam', 1), ('siti', 1), ('khadijah', 1), ('habib', 1), ('hanif', 1), ('baca', 1), ('qasidah', 1), ('kesukaan', 1)]
# ---
# text : RT @HangJeb47599466: Ekonomi RI Tumbuh 5%, Ekonom UI: Tanpa Presiden Pun Bisa
#
# Welcome to the jungle
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#
# https://t.co/xKOG6Wqu6Z
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('hangjeb', 1), ('ekonomi', 1), ('ri', 1), ('tumbuh', 1), ('ekonom', 1), ('ui', 1), ('presiden', 1), ('welcome', 1)]
# ---
# text : RT @Ning198: @jagger86031021 @Sulisti14281557 Makin sayang sama barang krn bisa beli gantinya
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('ning', 1), ('jagger', 1), ('sulisti', 1), ('sayang', 1), ('barang', 1), ('krn', 1), ('beli', 1), ('gantinya', 1)]
# ---
# text : @EDitektif @MichelAdamAnyar Kemanusiaan berpihak pd kebenaran , kedzoliman menghakimi tanpa nurani
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#
# ✊✊✊✊
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('editektif', 1), ('micheladamanyar', 1), ('kemanusiaan', 1), ('berpihak', 1), ('pd', 1), ('kebenaran', 1), ('kedzoliman', 1), ('menghakimi', 1), ('nurani', 1)]
# ---
# ...
# ---
# text : SITUS DENGAN RATING KEMENANGAN TERTINGGI !!
# BURUAN JOIN SEKARANG JUGA GUYS !!
# AGAR DAPAT RASAKAN MEJA HOKI NYA !!
# link : https://t.co/Z5Un6GHIzG
#
# #Bandarq #Dominoqq #JumatBerkah #UtangBanyakHarga2Melonjak #BawangPutihPartaiMerah #TigerBin #Sakong #AduQ #pokerv #pokeronline https://t.co/JoTFpjeGiS
# top 10 keywords: [('situs', 1), ('rating', 1), ('kemenangan', 1), ('tertinggi', 1), ('buruan', 1), ('join', 1), ('guys', 1), ('rasakan', 1), ('meja', 1), ('hoki', 1)]
# ---
# text : RT @Raysatria75: Assallamu'allaikum🙏
# Selamat pagi sobat &amp; sobit🙋
# Selamat hari Jum'at, jangan sampai tak Sholat Jum'at😵🔨
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Mel9njak https://t.co/mRYZ7KONma
# top 10 keywords: [('selamat', 2), ('jum', 2), ('at', 2), ('rt', 1), ('raysatria', 1), ('assallamu', 1), ('allaikum', 1), ('pagi', 1), ('sobat', 1), ('amp', 1)]
# ---
# text : RT @An0nymous_02: Hutang membengkak
# Ekonomi mangkrak
#
# Meningkatnya total hutang dpt bermakna positif n negatif. Berbagai pendekatan analisis dpt digunakan.
#
# Tapi yg jelas, rakyt yg mrasakn.
# Tagar pagi ini 👇👇👇
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#
# met pagii...  @jatila11 😘
# top 10 keywords: [('hutang', 2), ('dpt', 2), ('yg', 2), ('utangbanyakhargamelonjak', 2), ('rt', 1), ('annymous', 1), ('membengkak', 1), ('ekonomi', 1), ('mangkrak', 1), ('meningkatnya', 1)]
# ---
# text : RT @riani_212: Pagi tweeps.. Tagar hari ni.. #UtangBanyakHarga2Melonjak
#
# Yuk sambil siap2 ikutan lomba agustusan..
# Kita Rayakan Kemerdekaan RI bersama TNT 😊 https://t.co/qGrKgNVauE
# top 10 keywords: [('rt', 1), ('riani', 1), ('pagi', 1), ('tweeps', 1), ('tagar', 1), ('ni', 1), ('utangbanyakhargamelonjak', 1), ('yuk', 1), ('ikutan', 1), ('lomba', 1)]
# ---
# text : RT @uman_2009: Suasana negeri ini semakin tak ramah dengan rakyatnya.
#
# Harga melambung tinggi, nyari kerjaan semakin sulit, daya beli masyarakat anjlok.
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/GaljBFajKs
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('uman', 1), ('suasana', 1), ('negeri', 1), ('ramah', 1), ('rakyatnya', 1), ('harga', 1), ('melambung', 1), ('nyari', 1)]
# ---
# text : Keduanya bukanlah politisi yang taat pada ulama dan komando IB HRS. Jadi sikap kita cukup mengabaikan saja setiap manuver ataupun statement2 yg mereka keluarkan pada publik. Istilahnya, diabaikan saja :D.
#
# https://t.co/NdC8FgsegS
#
# #UtangBanyakHarga2Melonjak https://t.co/n68engZ0Qq
# top 10 keywords: [('politisi', 1), ('taat', 1), ('ulama', 1), ('komando', 1), ('ib', 1), ('hrs', 1), ('sikap', 1), ('mengabaikan', 1), ('manuver', 1), ('statement', 1)]
# ---
# text : @Muslimi63489533 @jengkelin080 @GilangBudi13 @GendisManis16 @Al_Fakir_ @DazaiSan08 @Momon_Egen @_Konnichiwa31_ @Lelepon16 @ScouserHandry @JengSrie080 @MrBin008 @UllbimaNtb Bahlul
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('muslimi', 1), ('jengkelin', 1), ('gilangbudi', 1), ('gendismanis', 1), ('alfakir', 1), ('dazaisan', 1), ('momonegen', 1), ('konnichiwa', 1), ('lelepon', 1), ('scouserhandry', 1)]
# ---
# text : @Profeson9 @Billy_Lagee @MichelAdamAnyar @RyizondR @RissaRR02 @RismaRichi @Bawel_Girl @M_G1LANG @elamawar1 @ParicaraNyai @DuchessOfPanda @amira_swandary @NurmajadVozdh @BidadariOposisi @AmaZanea00 @Shyin90 @PutriAi15784229 Pagi
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('profeson', 1), ('billylagee', 1), ('micheladamanyar', 1), ('ryizondr', 1), ('rissarr', 1), ('rismarichi', 1), ('bawelgirl', 1), ('mglang', 1), ('elamawar', 1), ('paricaranyai', 1)]
# ---
# text : @babaosman1299 Banget...
# kita diajarkan lihat orang lain menderita  harus diam saja. kalau dibantu kena batunya
#
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('babaosman', 1), ('banget', 1), ('diajarkan', 1), ('lihat', 1), ('orang', 1), ('menderita', 1), ('diam', 1), ('dibantu', 1), ('kena', 1), ('batunya', 1)]
# ---
# text : @Muslimi63489533 @jengkelin080 @GilangBudi13 @GendisManis16 @Al_Fakir_ @DazaiSan08 @Momon_Egen @_Konnichiwa31_ @Lelepon16 @ScouserHandry @JengSrie080 @MrBin008 @UllbimaNtb Gila
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('muslimi', 1), ('jengkelin', 1), ('gilangbudi', 1), ('gendismanis', 1), ('alfakir', 1), ('dazaisan', 1), ('momonegen', 1), ('konnichiwa', 1), ('lelepon', 1), ('scouserhandry', 1)]
# ---
# text : @aiek_esthreem TAGARNYA MSH NGAMBANG DITENGAH TENGAH TAGAR DUNIA.....
# YO DI GAS SEKENCENG KENCENG NYA SOBAT SMUA......
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/tjrNPbu51S
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('aiekesthreem', 1), ('tagarnya', 1), ('msh', 1), ('ngambang', 1), ('ditengah', 1), ('tagar', 1), ('dunia', 1), ('yo', 1), ('gas', 1)]
# ---
# text : RT @bangagoeng96: Lah kan sekarang emang rata² barang impor,, kalo ga salah beras impor, garam impor 😁😁
#
# #UtangBanyakHarga2Melonjak https://t.co/dwSMxkTrvm
# top 10 keywords: [('impor', 3), ('rt', 1), ('bangagoeng', 1), ('emang', 1), ('barang', 1), ('kalo', 1), ('ga', 1), ('salah', 1), ('beras', 1), ('garam', 1)]
# ---
# text : @budimandjatmiko @bandabening Jadi yg berbahaya itu sebenarnya yg mana menurut Bang Budi? PKI apa HTI? Monggo dijawab, pengen tau gw yg bahaya yg mana?
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('yg', 4), ('utangbanyakhargamelonjak', 2), ('budimandjatmiko', 1), ('bandabening', 1), ('berbahaya', 1), ('bang', 1), ('budi', 1), ('pki', 1), ('hti', 1), ('monggo', 1)]
# ---
# text : @MarcoSatria02 @NKRI_RI @aiek_esthreem @Etam394gmailco1 @rizkikitri @VanYrvanz Semoga kita termasuk dalam golongan hamdhan syakuro... aamiin..
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('marcosatria', 1), ('nkriri', 1), ('aiekesthreem', 1), ('etamgmailco', 1), ('rizkikitri', 1), ('vanyrvanz', 1), ('semoga', 1), ('golongan', 1), ('hamdhan', 1)]
# ---
# text : @smaya96 @021_P354W1K @lGrabo13 @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @hera_loebs Done kaka
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('smaya', 1), ('pwk', 1), ('lgrabo', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1)]
# ---
# text : RT @anoegrohoID: @MichelAdamAnyar Assalamualaikum wr wb 🙏😇
# #UtangBanyakHarga2Melonjak
# Selamat pagi ntuk semua pejuang oposisi 🙂
# #UtangBanyakHarga2Melonjak
#
# Jangan lupa sarapan dan tentu ngopi ☕️😇
# Biar semangat tetap terjaga 💪
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('anoegrohoid', 1), ('micheladamanyar', 1), ('assalamualaikum', 1), ('wr', 1), ('wb', 1), ('selamat', 1), ('pagi', 1), ('ntuk', 1)]
# ---
# text : @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @BidadariOposisi @hera_loebs @lGrabo13 done
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1), ('kolakvi', 1), ('aiekesthreem', 1)]
# ---
# text : @An0nymous_02 @jatila11 Rakyat merasakan Tuntutan Biaya Beban Berat, Ekonomi Kusut dan Sulit, @gusmusgusmu : Negara Haha Hihi
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('annymous', 1), ('jatila', 1), ('rakyat', 1), ('merasakan', 1), ('tuntutan', 1), ('biaya', 1), ('beban', 1), ('berat', 1), ('ekonomi', 1)]
# ---
# text : Utang sudah menumpuk, harga-harga pada melonjak naik,
# itu menteri kerja gk ya,
# apa hanya kerja untuk kantong sendiri?
#
# #UtangBanyakHarga2Melonjak
#
# https://t.co/Nt1WWbTSwv
# top 10 keywords: [('harga', 2), ('kerja', 2), ('utang', 1), ('menumpuk', 1), ('melonjak', 1), ('menteri', 1), ('gk', 1), ('ya', 1), ('kantong', 1), ('utangbanyakhargamelonjak', 1)]
# ---
# text : Inilah keturunan bani togog !
# gak jauh beda goblok nya sama cebong anyut yang suka makanin kotoran ,,
#
# Klo mo tau ,baca buku sejarah.
# Klo gak suka ame gubernur dki gosah mojokin !
#
# Idup elu terlalu indah di kolem yang butek🙏😁
#
# #UtangBanyakHarga2Melonjak https://t.co/XjhmMWvH77
# top 10 keywords: [('gak', 2), ('suka', 2), ('klo', 2), ('keturunan', 1), ('bani', 1), ('togog', 1), ('beda', 1), ('goblok', 1), ('nya', 1), ('cebong', 1)]
# ---
# text : RT @Ryizond08: @nochebonx @RismaRH02 procold kali ya kang 😆😆
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# Suek bener rezim penguasa skrg ini
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('ryizond', 1), ('nochebonx', 1), ('rismarh', 1), ('procold', 1), ('kali', 1), ('ya', 1), ('kang', 1), ('suek', 1)]
# ---
# text : @KingPurw4 @aniesbaswedan @faizalassegaf @gusmusgusmu @susipudjiastuti Somplax tingkat dewa.
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('kingpurw', 1), ('aniesbaswedan', 1), ('faizalassegaf', 1), ('gusmusgusmu', 1), ('susipudjiastuti', 1), ('somplax', 1), ('tingkat', 1), ('dewa', 1)]
# ---
# text : Ekonomi defisit, utang membengkak, harga naik, impor produk jalan terus, devisa tetap.........kemana ujung perekonomian ini swbenarnya
# #UtangBanyakHarga2Melonjak https://t.co/f87jYhmS4N
# top 10 keywords: [('ekonomi', 1), ('defisit', 1), ('utang', 1), ('membengkak', 1), ('harga', 1), ('impor', 1), ('produk', 1), ('jalan', 1), ('devisa', 1), ('kemana', 1)]
# ---
# text : RT @AliyahIsmail4: @MichelAdamAnyar Mentang'" Mata sdh rabun, aku pikir ngucapin assalamualaikum 😂😂, ampe mataku nyureng" 😂😂
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('aliyahismail', 1), ('micheladamanyar', 1), ('mentang', 1), ('mata', 1), ('sdh', 1), ('rabun', 1), ('pikir', 1), ('ngucapin', 1)]
# ---
# text : WOOOIIIIII BANI TOGOG MEDIA TOGOG REJIM TOGOG.....INI YG LOE PUJA PUJA ELUK ELUKAN.....AMIT AMIT DAH!!!
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/pgD4uP2ZVG
# top 10 keywords: [('togog', 3), ('puja', 2), ('amit', 2), ('utangbanyakhargamelonjak', 2), ('woooiiiiii', 1), ('bani', 1), ('media', 1), ('rejim', 1), ('yg', 1), ('loe', 1)]
# ---
# text : Daun bungkus memanjangkan dan menebalkan penis 400k
# Hajar jahanam 100k
# Waterbased lubricant monogatari dengan formula anti sakit 200k
# Waterbased lubricant same texture dan warna seperti sperma 200k
# Line @anyone795 atau dm
# #IslamYesKhilafahNOW
# #Wendy
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('k', 4), ('waterbased', 2), ('lubricant', 2), ('daun', 1), ('bungkus', 1), ('memanjangkan', 1), ('menebalkan', 1), ('penis', 1), ('hajar', 1), ('jahanam', 1)]
# ---
# text : Ni flagship samsung harga launchingnya dari taon ke taon naik
# Apa mungkin karena
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
#
# https://t.co/xYYb0JUQpe
# top 10 keywords: [('taon', 2), ('utangbanyakhargamelonjak', 2), ('ni', 1), ('flagship', 1), ('samsung', 1), ('harga', 1), ('launchingnya', 1)]
# ---
# text : @gusmusgusmu Alaikum salam. Wr. Wb.
#
# Kan slalu terkesan, terkenang, "belaian" Halus mu Gus, utk Panitia Negeri Haha Hihi....😁😁
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('gusmusgusmu', 1), ('alaikum', 1), ('salam', 1), ('wr', 1), ('wb', 1), ('slalu', 1), ('terkesan', 1), ('terkenang', 1), ('belaian', 1)]
# ---
# text : @MichelAdamAnyar Karna otaknya terbalik kebanyakan makan t**k, akhirnya FPI yg dikutuk n dicaci di-bully.
# Somplak....
#
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('micheladamanyar', 1), ('karna', 1), ('otaknya', 1), ('terbalik', 1), ('kebanyakan', 1), ('makan', 1), ('k', 1), ('fpi', 1), ('yg', 1), ('dikutuk', 1)]
# ---
# text : Assalamualiakum
#
# Pagi sobat tweeps jumat barokah perbanyak doa,istiqhfar dan sholawat
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/88lKKVXH17
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('assalamualiakum', 1), ('pagi', 1), ('sobat', 1), ('tweeps', 1), ('jumat', 1), ('barokah', 1), ('perbanyak', 1), ('doa', 1), ('istiqhfar', 1)]
# ---
# text : RT @DwiNining3: @021_P354W1K @_andy_ch @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @BidadariOposisi @hera_loebs @lGrabo13 Done
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('rt', 1), ('dwinining', 1), ('pwk', 1), ('andych', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1)]
# ---
# text : @ProfesorCiBar @NKRI_RI @aiek_esthreem @CuteP4nd4 @OurLove_Yuki @HDouboegiez @Ru__Chee @KiJaga_Baya @Cantiikkk___693 @khalsa86_mdn @HaqYang @Pohara5 @VanYrvanz @NongNayara @Majapahitprabu @dyanr99 @julie_my_name @Orang_Atjeh Baik prof.. cuman lg kecewa Euh.. #UtangBanyakHarga2Melonjak
# Vangke
# top 10 keywords: [('profesorcibar', 1), ('nkriri', 1), ('aiekesthreem', 1), ('cutepnd', 1), ('ourloveyuki', 1), ('hdouboegiez', 1), ('ruchee', 1), ('kijagabaya', 1), ('cantiikkk', 1), ('khalsamdn', 1)]
# ---
# text : RT @jatila11: @Profeson9 @Billy_Lagee @MichelAdamAnyar @RyizondR @RissaRR02 @RismaRichi @Bawel_Girl @M_G1LANG @elamawar1 @ParicaraNyai @DuchessOfPanda @amira_swandary @NurmajadVozdh @BidadariOposisi @AmaZanea00 @Shyin90 @PutriAi15784229 Slnat pagi. #UtangBanyakHarga2Melonjak
# top 10 keywords: [('rt', 1), ('jatila', 1), ('profeson', 1), ('billylagee', 1), ('micheladamanyar', 1), ('ryizondr', 1), ('rissarr', 1), ('rismarichi', 1), ('bawelgirl', 1), ('mglang', 1)]
# ---
# text : @aiek_esthreem @p3jalan @lGrabo13 @itsmeajalah3 @sbe_f1 @Mia_suhandi_ @bocah_kinei @RissaRR02 @AmoebaF2 @luvanne88 @NiCemplux @Cte_cute @bangjuned_02neo @bang_baret @taufikkaton @vairply @adeira78 @Ism0y0_jati @LLSandy1 @MustbeOvie @Hardianton1 @tigers_killer #UtangBanyakHarga2Melonjak
# top 10 keywords: [('aiekesthreem', 1), ('pjalan', 1), ('lgrabo', 1), ('itsmeajalah', 1), ('sbef', 1), ('miasuhandi', 1), ('bocahkinei', 1), ('rissarr', 1), ('amoebaf', 1), ('luvanne', 1)]
# ---
# text : Bukan Urusan Saya......
#
# Selamat Pagi Sahabat Twitt.....
#
# Jum'at Barokah 🙏😇
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak https://t.co/5970YZyMdr
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('urusan', 1), ('selamat', 1), ('pagi', 1), ('sahabat', 1), ('twitt', 1), ('jum', 1), ('at', 1), ('barokah', 1)]
# ---
# text : @ustadtengkuzul Semoga yg belum melek bisa segera melek tadz...sepertinya mata mereka sudah terbutakan dengan racun2 dari media mainstream yang seolah-olah negara kita ini ok ok aja, padahal mah sebaliknya.
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('melek', 2), ('ok', 2), ('utangbanyakhargamelonjak', 2), ('ustadtengkuzul', 1), ('semoga', 1), ('yg', 1), ('tadz', 1), ('mata', 1), ('terbutakan', 1), ('racun', 1)]
# ---
# text : @021_P354W1K @nancyfabiola99 @lGrabo13 @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @Kolak_VI @aiek_esthreem @hera_loebs Tagarnya mana KK
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('pwk', 1), ('nancyfabiola', 1), ('lgrabo', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('kolakvi', 1)]
# ---
# text : @NKRI_RI @aiek_esthreem @Etam394gmailco1 @semut_ireng98 @MarcoSatria02 @VanYrvanz aminn....semoga menjadi berkah di pagi yg hujan ini😀
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('nkriri', 1), ('aiekesthreem', 1), ('etamgmailco', 1), ('semutireng', 1), ('marcosatria', 1), ('vanyrvanz', 1), ('aminn', 1), ('semoga', 1), ('berkah', 1), ('pagi', 1)]
# ---
# text : @lGrabo13 @021_P354W1K @Kanseulir @UyokBack @hacknet__71 @MichelAdamAnyar @4NN4_5U3Z4NN @nancyfabiola99 @Kolak_VI @aiek_esthreem @hera_loebs Padahal udah pake farpum satu botol, masih ketahuan juga 😁😁
#
# #UtangBanyakHarga2Melonjak
# #UtangBanyakHarga2Melonjak
# top 10 keywords: [('utangbanyakhargamelonjak', 2), ('lgrabo', 1), ('pwk', 1), ('kanseulir', 1), ('uyokback', 1), ('hacknet', 1), ('micheladamanyar', 1), ('nnuznn', 1), ('nancyfabiola', 1), ('kolakvi', 1)]
# ---

# %%
data['text'] = data['text'].map(lambda d: str(d))
data['tokens'] = data['text'].progress_map(lambda d: tokenizer(d))
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=5, analyzer='word', ngram_range=(1, 2), stop_words='english')
vz = vectorizer.fit_transform(list(data['tokens'].map(lambda tokens: ' '.join(tokens))))
vz.shape
# Out:
# (200, 177)

# %%
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
tfidf = pd.DataFrame(columns=['tfidf']).from_dict(dict(tfidf), orient='index')
tfidf.columns = ['tfidf']

# %%
tfidf.tfidf.hist(bins=25, figsize=(15,7))

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
def plot_word_cloud(terms):
    text = terms.index
    text = ' '.join(list(text))
    # lower max_font_size
    wordcloud = WordCloud(max_font_size=40).generate(text)
    plt.figure(figsize=(25, 25))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
plot_word_cloud(tfidf.sort_values(by=['tfidf'], ascending=False).head(40))

# %%
plot_word_cloud(tfidf.sort_values(by=['tfidf'], ascending=True).head(40))
